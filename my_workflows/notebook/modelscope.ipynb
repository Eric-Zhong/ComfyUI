# %% [markdown]
# # modelscope core

# %%
# 模型下载
import os
from modelscope import snapshot_download

current_dir = os.getcwd()

comfyui_root_dir = os.path.dirname(os.path.dirname(current_dir))
comfyui_model_dir = os.path.join(comfyui_root_dir, "models")

print("current_dir:", current_dir)  # 输出当前目录'

# %% [markdown]
# # 场景

# %% [markdown]
# ## 室内设计

# %% [markdown]
# ### LoRa

# %% [markdown]
# #### Canopus-Interior-Architecture-0.1
#
# https://modelscope.cn/models/prithivMLmods/Canopus-Interior-Architecture-0.1

# %%
#模型下载
modelscope_model_id = 'prithivMLmods/Canopus-Interior-Architecture-0.1'
local_dir = ''
model_dir = snapshot_download('prithivMLmods/Canopus-Interior-Architecture-0.1')
