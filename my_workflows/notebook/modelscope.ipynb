# %% [markdown]
# # modelscope core

# %%
# 模型下载
import os
from modelscope import snapshot_download

current_dir = os.getcwd()

comfyui_root_dir = os.path.dirname(os.path.dirname(current_dir))

# model/*
comfyui_models_dir = os.path.join(comfyui_root_dir, "models")
comfyui_models_loras_dir = os.path.join(comfyui_models_dir, "loras")

# custom_nodes/*
comfyui_custom_nodes_dir = os.path.join(comfyui_root_dir, "custom_nodes")

print("Current dir:", current_dir)
print("ComfyUI dir:", comfyui_root_dir)
print("Models dir:", comfyui_models_dir)
print("LoRa dir:", comfyui_models_loras_dir)

print("custom nodes dir:", comfyui_custom_nodes_dir)
# Out:
# Current dir: z:\Service\ComfyUI\my_workflows\notebook
# ComfyUI dir: z:\Service\ComfyUI
# Models dir: z:\Service\ComfyUI\models
# custom nodes dir: z:\Service\ComfyUI\custom_nodes

# %% [markdown]
# # 场景

# %% [markdown]
# ## 室内设计
#
# 推荐B站Up主
# 匠大实验室: https://space.bilibili.com/30003184
# 来真的: https://space.bilibili.com/590784254 : https://civitai.com/user/laizhende/models
# AI设计研究室-帆哥: https://space.bilibili.com/2161614
# 建筑崔工: https://space.bilibili.com/488739006
# 言萧的AI画室: https://space.bilibili.com/2705253
# 大咦把狼-老王: https://space.bilibili.com/389793760
# SD-AI模型作者推荐-XSarchitectural: https://www.bilibili.com/video/BV1a8411D78h
#
# 推荐大纲
# - SD 1.5 室内建筑大模型 = 18个
# - SDXL Lora = 2个
# - SD 1.5 常规室内设计Lora = 61个
# - SD 1.5 功能室内设计Lora = 15个
# - SD 1.5 特殊风格室内设计Lora = 13个
# - SD 2.1 Lora = 22个
#
# ——【SD 1.5 模型】——
# - InteriorDesignSuperMix: https://civitai.com/models/85691
# - architecture_Interior_SDlife_Chiasedamme_V6.0: https://civitai.com/models/126839
# - architecture_Interior_SDlife_Chiasedamme_V7.0: https://civitai.com/models/128722
# - architecture_Interior_SDlife_Chiasedamme_V8.0: https://civitai.com/models/128754
# - architecture_Interior_SDlife_Chiasedamme_V9.0: https://civitai.com/models/128780
# - architecture_Interior_SDlife_Chiasedamme_V10.0: https://civitai.com/models/137520
# - Interior Design: https://civitai.com/models/54699
# - interior_smgs: https://civitai.com/models/114018
# - XSarchitectural-InteriorDesign-ForXSLora: https://civitai.com/models/28112
# - XSMerge-RealisticVisionV3-ForArchitectural: https://civitai.com/models/102895
# - XSAchi-InteriorDesginV5ForCN: https://civitai.com/models/51830
# - Library interior design v0.01 图书馆室内设计: https://civitai.com/models/60163
# - Museum &amp; Exhibition v1.0 博物馆与展览1.0: https://civitai.com/models/73008
# - GDM Luxury Modern Interior Design Ultimate Checkpoint GDM奢华现代室内设计 最终版 大模型: https://civitai.com/models/75888
# - INDOORS_3.0_v1.5_mdbz: https://civitai.com/models/125651
# - dvArch - Multi-Prompt Architecture Tuned Model: https://civitai.com/models/8552?modelVersionId=32534
# - AnyBuild 室内设计与建筑外观: https://civitai.com/models/128950
# - 通用性：建筑/室内/人物 Mr_Mc_Fanyong_V15_1.2: https://civitai.com/models/72883
#
# ——【SDXL Lora】——
# - Santorini 圣托里尼（地中海）风格: https://civitai.com/models/104644
# - Tiny Home Concept 微型家庭概念: https://civitai.com/models/117761
# - Javanese Interior Design 爪哇风格室内设计: https://civitai.com/models/108110
# - HIVE-InteriorDesign | 蜂巢仿生室内设计: https://civitai.com/models/117515
# - Art nouveau style interior design 新艺术风格的室内设计: https://civitai.com/models/110851
# - 软科幻，室内/建筑/Mr_Mc_BokK_V1: https://civitai.com/models/86185
# - Futuristic Interior - composer 未来风格室内: https://civitai.com/models/116897
# - Futuristic Interior - refiner 未来风格室内: https://civitai.com/models/116899
#
# ——【SD2.1 Lora】——
# - Minimalist_interior_design 极简主义的室内设计: https://civitai.com/models/107167
# - Baroque interior design 巴洛克风格室内设计: https://civitai.com/models/107834
# - Antique style interior design 古董风格室内设计: https://civitai.com/models/108295
# - African style interior design 非洲风格室内设计: https://civitai.com/models/108223
# - Art deco style interior design 装饰艺术风格室内设计: https://civitai.com/models/108427
# - Art nouveau style interior design 新艺术风格的室内设计: https://civitai.com/models/109527
# - Arabic style interior design 阿拉伯风格室内设计: https://civitai.com/models/108304
# - Bionic futuristic interior design 仿生未来派室内设计: https://civitai.com/models/108604
# - Brutalism style interior design 野蛮风格的室内设计: https://civitai.com/models/109532
# - Boho style interior design 波西米亚风格的室内设计: https://civitai.com/models/109862
# - English style interior design 英伦风格室内设计: https://civitai.com/models/109554
# - Belgian style interior design 比利时风格的室内设计: https://civitai.com/models/109548
# - Greek style interior design 希腊风格室内设计: https://civitai.com/models/110298
# - Modern interior design 现代室内设计: https://civitai.com/models/109790
# - Indonesian style interior design 印尼风格室内设计: https://civitai.com/models/110305
# - Gothic style interior design 哥特式风格室内设计: https://civitai.com/models/110288
# - Italian style interior design 意大利风格室内设计: https://civitai.com/models/110898
# - Irish style interior design 爱尔兰风格室内设计: https://civitai.com/models/111737
# - Geometric style interior design 几何样式室内设计: https://civitai.com/models/111732
# - kitsch style interior design 媚俗风格室内设计: https://civitai.com/models/112168
# - Indian style interior design 印度风格室内设计: https://civitai.com/models/111746
# - Contemporarie style interior design 当代风格室内设计: https://civitai.com/models/112158

# %% [markdown]
# ### LoRa

# %% [markdown]
# #### Canopus-Interior-Architecture-0.1
#
# https://modelscope.cn/models/prithivMLmods/Canopus-Interior-Architecture-0.1

# %%
# 模型下载
modelscope_model_id = "prithivMLmods/Canopus-Interior-Architecture-0.1"
local_dir = os.path.join(
    comfyui_models_loras_dir, "prithivMLmods/Canopus-Interior-Architecture-0.1"
)
model_dir = snapshot_download(
    model_id="prithivMLmods/Canopus-Interior-Architecture-0.1", 
    local_dir=local_dir
)
# Out:
# ...
# 2025-03-31 10:05:57,035 - modelscope - INFO - Got 6 files, start to download ...
# Processing 6 items:   0%|          | 0.00/6.00 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ...
# Processing 6 items:  17%|█▋        | 1.00/6.00 [00:00<00:01, 2.92it/s]
# ...
# Processing 6 items:  50%|█████     | 3.00/6.00 [00:00<00:00, 3.06it/s]
#
#
#
#
#
#
# ...
#
#
# ...
# Processing 6 items:  83%|████████▎ | 5.00/6.00 [00:01<00:00, 5.81it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ...
